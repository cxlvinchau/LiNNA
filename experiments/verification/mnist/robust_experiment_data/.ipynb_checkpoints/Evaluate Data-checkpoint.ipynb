# %%
import pandas as pd

# %%
df = pd.read_csv("20230122-062257.csv")

# %%
df
# Out:
#     Unnamed: 0      network  image_idx  target_cls  delta  \
# 0            0  MNIST_3x100          0           5   0.02
# 1            1  MNIST_3x100          0           5   0.05
# 2            2  MNIST_3x100          1           0   0.02
# 3            3  MNIST_3x100          1           0   0.05
# 4            4  MNIST_3x100          2           4   0.02
# 5            5  MNIST_3x100          2           4   0.05
# 6            6  MNIST_3x100          3           1   0.02
# 7            7  MNIST_3x100          3           1   0.05
# 8            8  MNIST_3x100          4           9   0.02
# 9            9  MNIST_3x100          4           9   0.05
# 10          10  MNIST_3x100          5           2   0.02
# 11          11  MNIST_3x100          5           2   0.05
# 12          12  MNIST_3x100          6           1   0.02
# 13          13  MNIST_3x100          6           1   0.05
# 14          14  MNIST_3x100          7           3   0.02
# ...

# %%
# Out:
#     Unnamed: 0      network  image_idx  target_cls  delta  \
# 1            1  MNIST_3x100          0           5   0.05
# 9            9  MNIST_3x100          4           9   0.05
# 11          11  MNIST_3x100          5           2   0.05
# 13          13  MNIST_3x100          6           1   0.05
# 17          17  MNIST_3x100          8           1   0.05
#
#     linna_time (seconds)  linna_timeout linna_is_real_cex linna_result  \
# 1               1.881908          False              True          sat
# 9               1.953323          False              True          sat
# 11              1.135106          False              True          sat
# 13              1.233305          False              True          sat
# 17              1.040402          False              True          sat
#
#     linna_error  marabou_time (seconds)  marabou_timeout marabou_result  \
# 1         False              601.118845             True        timeout
# ...
