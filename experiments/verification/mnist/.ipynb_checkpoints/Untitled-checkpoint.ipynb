# %%
import pandas as pd

# %%
df = pd.read_csv("20230130-105819.csv")

# %%
df
# Out:
#      Unnamed: 0      network  image_idx  target_cls  delta   rr  \
# 0             0  MNIST_3x100          0           5   0.02  0.2
# 1             1  MNIST_3x100          0           5   0.05  0.2
# 2             2  MNIST_3x100          0           5   0.02  0.5
# 3             3  MNIST_3x100          0           5   0.05  0.5
# 4             4  MNIST_3x100          0           5   0.02  0.8
# ..          ...          ...        ...         ...    ...  ...
# 310         310  MNIST_3x100         51           0   0.02  0.8
# 311         311  MNIST_3x100         51           0   0.05  0.8
# 312         312  MNIST_3x100         52           7   0.02  0.2
# 313         313  MNIST_3x100         52           7   0.05  0.2
# 314         314  MNIST_3x100         52           7   0.02  0.5
#
#      linna_time (seconds)  linna_timeout linna_is_real_cex  \
# 0                2.112182          False               NaN
# 1                0.973948          False             False
# ...
